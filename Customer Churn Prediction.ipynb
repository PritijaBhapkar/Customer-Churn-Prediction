# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Telco-Customer-Churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# In describe we can only view numerical data
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
sns.countplot(x='Churn', data=df)
plt.show()

# %%
df['Churn'].value_counts()

# Highly imbalanced data
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df = df.dropna(subset=['TotalCharges'])

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['tenure'].max()
# Out:
# 72

# %%
# Lrt's group tenure

bins = [0, 12, 24, 36, 48, 60, 72]
labels = ['1-12', '13-24', '25-36', '37-48', '49-60', '61-72']
df['TenureGroup'] = pd.cut(df['tenure'], bins=bins, labels=labels, right=True)
df['TenureGroup']
# Out:
# 0        1-12
# 1       25-36
# 2        1-12
# 3       37-48
# 4        1-12
#         ...
# 7038    13-24
# 7039    61-72
# 7040     1-12
# 7041     1-12
# 7042    61-72
# Name: TenureGroup, Length: 7032, dtype: category
# Categories (6, object): ['1-12' < '13-24' < '25-36' < '37-48' < '49-60' < '61-72']

# %%
df['TenureGroup'].value_counts()
# Out:
# 1-12     2175
# 61-72    1407
# 13-24    1024
# 25-36     832
# 49-60     832
# 37-48     762
# Name: TenureGroup, dtype: int64

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.drop(columns=['customerID', 'tenure'], axis=1, inplace=True)
df
# Out:
#       gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female              0     Yes         No           No  No phone service
# 1       Male              0      No         No          Yes                No
# 2       Male              0      No         No          Yes                No
# 3       Male              0      No         No           No  No phone service
# 4     Female              0      No         No          Yes                No
# ...      ...            ...     ...        ...          ...               ...
# 7038    Male              0     Yes        Yes          Yes               Yes
# 7039  Female              0     Yes        Yes          Yes               Yes
# 7040  Female              0     Yes        Yes           No  No phone service
# 7041    Male              1     Yes         No          Yes               Yes
# 7042    Male              0      No         No          Yes                No
#
# ...

# %% [markdown]
# ###  Univariate Analysis

# %%
plt.figure(figsize=(12,6), dpi=200)
for i, predictor in enumerate(df.drop(columns=['Churn', 'TotalCharges', 'MonthlyCharges'])):
    plt.figure()
    sns.countplot(data=df, x=predictor, hue='Churn')

# %% [markdown]
# Converting categorical data (churn) into numerical

# %%
df['Churn'] = np.where(df.Churn == 'Yes',1,0)

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female              0     Yes         No           No  No phone service
# 1       Male              0      No         No          Yes                No
# 2       Male              0      No         No          Yes                No
# 3       Male              0      No         No           No  No phone service
# 4     Female              0      No         No          Yes                No
# ...      ...            ...     ...        ...          ...               ...
# 7038    Male              0     Yes        Yes          Yes               Yes
# 7039  Female              0     Yes        Yes          Yes               Yes
# 7040  Female              0     Yes        Yes           No  No phone service
# 7041    Male              1     Yes         No          Yes               Yes
# 7042    Male              0      No         No          Yes                No
#
# ...

# %% [markdown]
# Converting all categorical variables into dummy variables

# %%
df_dummies = pd.get_dummies(df)
df_dummies
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0                 0           29.85         29.85      0              1
# 1                 0           56.95       1889.50      0              0
# 2                 0           53.85        108.15      1              0
# 3                 0           42.30       1840.75      0              0
# 4                 0           70.70        151.65      1              1
# ...             ...             ...           ...    ...            ...
# 7038              0           84.80       1990.50      0              0
# 7039              0          103.20       7362.90      0              1
# 7040              0           29.60        346.45      0              1
# 7041              1           74.40        306.60      1              0
# 7042              0          105.65       6844.50      0              0
#
#       gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# ...

# %%
sns.lmplot(x='MonthlyCharges', y='TotalCharges', data=df)
# Highly correlated

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='Set3')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
churn = df.loc[df['Churn'] == 1]
Not_churn = df.loc[df['Churn'] == 0] 

# 1 --> likely to churn
# 0 --> likely to not-churn

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.countplot(churn, x = 'Partner', hue ='gender')
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.countplot(Not_churn, x = 'Partner', hue ='gender')
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.countplot(churn, x = 'PaymentMethod', hue ='gender')
# Electronic Check are highly churners
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='count'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.countplot(churn, x = 'Contract', hue ='gender')
# Month-to-month are likely to churn due to no contract
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %% [markdown]
# ### Model Building

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df_dummies
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0                 0           29.85         29.85      0              1
# 1                 0           56.95       1889.50      0              0
# 2                 0           53.85        108.15      1              0
# 3                 0           42.30       1840.75      0              0
# 4                 0           70.70        151.65      1              1
# ...             ...             ...           ...    ...            ...
# 7038              0           84.80       1990.50      0              0
# 7039              0          103.20       7362.90      0              1
# 7040              0           29.60        346.45      0              1
# 7041              1           74.40        306.60      1              0
# 7042              0          105.65       6844.50      0              0
#
#       gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# ...

# %%
# Creating X(independent) and Y(dependent/ target) variables

# %%
x = df_dummies.drop('Churn', axis=1)
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85              1            0
# 1                 0           56.95       1889.50              0            1
# 2                 0           53.85        108.15              0            1
# 3                 0           42.30       1840.75              0            1
# 4                 0           70.70        151.65              1            0
# ...             ...             ...           ...            ...          ...
# 7038              0           84.80       1990.50              0            1
# 7039              0          103.20       7362.90              1            0
# 7040              0           29.60        346.45              1            0
# 7041              1           74.40        306.60              0            1
# 7042              0          105.65       6844.50              0            1
#
# ...

# %%
y = df_dummies['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7032, dtype: int32

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
# Decision Tree
classifier = DecisionTreeClassifier(criterion='gini', max_depth=4)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
pred_train = classifier.predict(x_train)
pred_test  = classifier.predict(x_test)

print('Training Accuracy : ', accuracy_score(y_train, pred_train))
print('Testing Accuracy  : ', accuracy_score(y_test, pred_test))
# Out:
# Training Accuracy :  0.7966222222222222
# Testing Accuracy  :  0.7846481876332623

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      1033
#            1       0.61      0.51      0.56       374
#
#     accuracy                           0.78      1407
#    macro avg       0.72      0.70      0.71      1407
# weighted avg       0.77      0.78      0.78      1407

# %%
print(confusion_matrix(y_test, pred_test))
# Out:
# [[913 120]
#  [183 191]]

# %%
# Random Forest
rf = RandomForestClassifier(n_estimators=100,criterion='gini', max_depth=4, random_state = 42)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=4, random_state=42)

# %%
y_pred = rf.predict(x_test)

# %%
pred_train = rf.predict(x_train)
pred_test  = rf.predict(x_test)

print('Training Accuracy : ', accuracy_score(y_train, pred_train))
print('Testing Accuracy  : ', accuracy_score(y_test, pred_test))
# Out:
# Training Accuracy :  0.7960888888888888
# Testing Accuracy  :  0.7874911158493249

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.95      0.87      1033
#            1       0.71      0.34      0.46       374
#
#     accuracy                           0.79      1407
#    macro avg       0.76      0.64      0.66      1407
# weighted avg       0.78      0.79      0.76      1407

# %% [markdown]
# ### Oversampling

# %%
# Highly imbalanced data, so to deal with this problem we will use oversampling

# %%
from  imblearn.over_sampling import SMOTE
smote_sampler = SMOTE()
x_sampled, y_sampled = smote_sampler.fit_resample(x,y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_sampled, y_sampled, test_size = 0.2, random_state =2)

# %%
classifier = DecisionTreeClassifier(criterion='gini', max_depth=4)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
pred_train = classifier.predict(x_train)
pred_test  = classifier.predict(x_test)

print('Training Accuracy : ', accuracy_score(y_train, pred_train))
print('Testing Accuracy  : ', accuracy_score(y_test, pred_test))
# Out:
# Training Accuracy :  0.801452784503632
# Testing Accuracy  :  0.8097773475314618

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80      1062
#            1       0.77      0.86      0.81      1004
#
#     accuracy                           0.81      2066
#    macro avg       0.81      0.81      0.81      2066
# weighted avg       0.81      0.81      0.81      2066

# %%
print(confusion_matrix(y_test, pred_test))
# Out:
# [[811 251]
#  [142 862]]

# %%
# For random forest

# %%
from  imblearn.over_sampling import SMOTE
smote_sampler = SMOTE()
x_sampled, y_sampled = smote_sampler.fit_resample(x,y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_sampled, y_sampled, test_size = 0.2, random_state =2)

# %%
# Random Forest
rf = RandomForestClassifier(n_estimators=100,criterion='gini', max_depth=4, random_state = 42)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=4, random_state=42)

# %%
pred_train = classifier.predict(x_train)
pred_test  = classifier.predict(x_test)

print('Training Accuracy : ', accuracy_score(y_train, pred_train))
print('Testing Accuracy  : ', accuracy_score(y_test, pred_test))
# Out:
# Training Accuracy :  0.8053268765133171
# Testing Accuracy  :  0.8083252662149081

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80      1062
#            1       0.77      0.86      0.81      1004
#
#     accuracy                           0.81      2066
#    macro avg       0.81      0.81      0.81      2066
# weighted avg       0.81      0.81      0.81      2066

# %%
# Saving model
import pickle

# %%
filename = 'model.save'

# %%
pickle.dump(rf, open(filename, 'wb'))

# %%
load_model = pickle.load(open(filename, 'rb'))

# %%
load_model.score(x_test, y_test)
# Out:
# 0.813649564375605
